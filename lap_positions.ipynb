# %%
import pandas as pd
lap_times = pd.read_csv('lap_times.csv')
race_841 = lap_times.query('raceId == 841')

# %%
lap_positions = pd.DataFrame({'lap': [i for i in range(1,59)]}, \
                             columns = ['lap', 'first_driver', 'second_driver', 'third_driver'])

# %%
for i in range(1,59): 
    k = i
    lap_positions.iloc[i-1, 0] = i
    lap_positions.iloc[i-1, 1] = race_841.query('lap == @k').iloc[0,1]
    lap_positions.iloc[i-1, 2] = race_841.query('lap == @k').iloc[0,2]
    lap_positions.iloc[i-1, 3] = race_841.query('lap == @k').iloc[0,3]

# %%
lap_positions
# Out:
#     lap first_driver second_driver third_driver
# 0     1           20             1            1
# 1     2           20             2            1
# 2     3           20             3            1
# 3     4           20             4            1
# 4     5           20             5            1
# 5     6           20             6            1
# 6     7           20             7            1
# 7     8           20             8            1
# 8     9           20             9            1
# 9    10           20            10            1
# 10   11           20            11            1
# 11   12           20            12            1
# 12   13           20            13            1
# 13   14           20            14            3
# 14   15           20            15            4
# 15   16           20            16            2
# 16   17           20            17            1
# 17   18           20            18            1
# 18   19           20            19            1
# 19   20           20            20            1
# 20   21           20            21            1
# 21   22           20            22            1
# 22   23           20            23            1
# 23   24           20            24            1
# 24   25           20            25            1
# 25   26           20            26            1
# 26   27           20            27            1
# 27   28           20            28            1
# 28   29           20            29            1
# 29   30           20            30            1
# 30   31           20            31            1
# 31   32           20            32            1
# 32   33           20            33            1
# 33   34           20            34            1
# 34   35           20            35            1
# 35   36           20            36            1
# 36   37           20            37            1
# 37   38           20            38            1
# 38   39           20            39            1
# 39   40           20            40            1
# 40   41           20            41            1
# 41   42           20            42            1
# 42   43           20            43            1
# 43   44           20            44            1
# 44   45           20            45            1
# 45   46           20            46            1
# 46   47           20            47            1
# 47   48           20            48            1
# 48   49           20            49            1
# 49   50           20            50            1
# 50   51           20            51            1
# 51   52           20            52            1
# 52   53           20            53            1
# 53   54           20            54            1
# 54   55           20            55            1
# 55   56           20            56            1
# 56   57           20            57            1
# 57   58           20            58            1
